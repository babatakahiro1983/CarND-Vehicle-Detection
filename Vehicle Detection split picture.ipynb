# %%
import numpy as np
import cv2
import tkinter.filedialog as tkfd
from lesson_functions import *
from scipy.ndimage.measurements import label

# Read movie
# clf_filename = tkfd.askopenfilename(title="select movie")
cap = cv2.VideoCapture('./project_video.mp4')
# cap = cv2.VideoCapture('./challenge_video.mp4')
# cap = cv2.VideoCapture('./harder_challenge_video.mp4')

# svc = joblib.load('vehicle_detector.pkl') 

# Buffer initialization
ret, frame = cap.read()

# Convert setting
# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# out = cv2.VideoWriter('vehicle_detection_result.avi',fourcc, 30.0, (frame.shape[1],frame.shape[0]))
cnt = 0

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:

        #######################################################################################################         
        draw_image = frame
        image = frame
        showed_image = image
#         showed_image = image
        
        # Show movie
        cv2.imwrite("./movie2/image"+str(10000 + cnt)+".jpg", showed_image)
        cv2.imshow('frame', showed_image)
        cnt = cnt + 1

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
# out.release()
cv2.destroyAllWindows()
